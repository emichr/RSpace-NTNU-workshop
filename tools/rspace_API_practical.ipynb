# %% [markdown]
# # RSpace API practical
#
# You can use the RSpace API through python to create, list, upload, and manage many aspects of your RSpace objects. However, some features can only be done through the RSpace user interface online.
#
# Use of the API can be complicated if all you want to do is perform simple tasks. However, if you want to e.g. replicate the same task many times, or if you want to integrate RSpace into your analysis workflow by automatically upload any results/plots/documents etc, the API can help and improve your efficiency and robustness.
#
# The Python API tools can be found on GitHub at [https://github.com/rspace-os/rspace-client-python](https://github.com/rspace-os/rspace-client-python). You should refer to the official github RSpace repository in the future, as the present notebook may run out of date.
#
# You can also read more about the RSpace API at [https://rspace.ntnu.no/public/apiDocs](https://rspace.ntnu.no/public/apiDocs).
#
# ## Requirements
#
# Use of the API through python depends on the `rspace_client==2.5.0` package found on both PyPi and conda. In addition, a few other requirements are useful. For __TEM__ analysis, it is advised that a repository for RSpace API use includes at least these packages:
#
# - rspace_client==2.5.0
# - pyxem==0.19.1
# - hyperspy
# - hyperspy-gui-ipywidgets
# - hyperspy-gui-traitsui
# - tabulate
# - jupyter
# - jupyterlab
# - matplotlib
# - numpy<2.0.0
# - scipy
# - markdown
# - json2html
# - pymdown-extensions
#
# ## Preparations
#
# In order to use the API through python, you will need to do some preparations first. Let us start by setting up an environment.
#
# ### Setting up environment
#
# Create a new environment for _pure_ RSpace use through conda:
#
# ```bash
# conda create -n RSpace -c conda-forge rspace_client=2.5.0 tabulate jupyter jupyterlab matplotlib numpy<2.0.0 scipy markdown json2html pymdown-extensions
# ```
#
# #### Pip
#
# The RSpace client can also be installed through pip:
#
# ```bash
# conda create -n RSpace pip pyxem=0.19.1 hyperspy hyperspy-gui-traitsui hyperspy-gui-ipywidgets tabulate jupyter jupyterlab matplotlib numpy<2.0.0 scipy markdown json2html pymdown-extensions
# conda activate RSpace
# pip install rspace_client==2.5.0
# ```
#
# ### API Key
# Next, you need to get your API key from RSpace. Your API key is _equivalent_ to a password, and should be treated as a secret. A few key points to remember is:
#
# - __NEVER__ share your API key
# - __NEVER__ include your API key directly in scripts or notebooks
# - Be __CAREFUL__ if you enter your API key as input to scripts through the command-console. It will be stored in readable clear text in the console log!
#
# We will get back to how to use your API key in a _more_ secure way later on.
#
# #### Getting your API Key
#
# To get your API key:
#
# 1. Log in to RSPace at [https://rspace.ntnu.no](https://rspace.ntnu.no)
# 2. Go to "My RSpace"
# 3. Go to "My Profile"
# 4. Scroll to the bottom and click "Generate API key"
# 5. Save the API key in a secure way. It will not be displayed again! Anyone with access to the API key will have full control of your RSpace.
#
# If your API key for some reason gets compromised, or if you lose it, you can always repeat the steps above to regenerate the key. This will render any previous API key invalid. You can also revoke the key if you want to disable API access altogether.
#
# #### Adding your key to the system environmental variables
#
# To use your API key in scripts or on notebooks without adding it as clear text to files or in the command line, you can instead add the API key to the system environmental variables. This allows you to get the API key through python with commands such as
#
# ```python
# import os
# os.getenv("RSPACE_API_KEY")
# ```
#
# How to add your API key to the system environmental variables varies from system to system.
#
# ##### Windows
#
# On Windows, you can add your API key to the system environmental variables by (see example images after the list):
#
# 1. Search for "environment" in the start menu (you should get a hit for "Edit the system environment variables").
# 2. Under "User variables for ..." click "New".
# 3. Enter a suitable variable name (e.g. "RSPACE_API_KEY") and enter the API key you got from RSpace as the value.
#
# <img src="../images/windows_edit_env_var_1.PNG" alt="Edit system environmental variables Windows 1" width="200"/>
#
# <img src="../images/windows_edit_env_var_2.PNG" alt="Edit system environmental variables Windows 2" width="200"/>
#
# <img src="../images/windows_edit_env_var_3.PNG" alt="Edit system environmental variables Windows 3" width="200"/>
#
# ##### Linux
#
# In linux you can add your RSpace API key to the system environment variables by editing your bashrc file (note that this involves storing the key in an unsecured text file and poses a potential security risk).
#
# Open bashrc in a text editor and add `export RSPACE_API_KEY=key` anywhere in the file. You can e.g. open the bashrc file with nano by running this command:
# ```bash
# nano ~/.bashrc
# ```
#
# ## Using the API
#
# You should now be able to use this notebook. Use of the API is relatively straight forward, and you can usually find good examples and demos at [https://github.com/rspace-os/rspace-client-python/tree/master/examples](https://github.com/rspace-os/rspace-client-python/tree/master/examples).
#
# Most of the API commands returns a dictionary with the response from the RSpace server.

# %%
from matplotlib import pyplot as plt
# %matplotlib notebook

import os
from tabulate import tabulate
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
import markdown
import json2html
import pandas as pd
import seaborn as sns

import hyperspy.api as hs
import pyxem as pxm

from rspace_client.eln.eln import ELNClient

def get_url_link(response):
    """
    Extracts a URL from an API response.
    
    Parameters
    ----------
    response: dict
        The API response.

    Returns
    -------
    url : str
        URL to the object on RSpace.

    """
    base_url = response['_links'][0]['link'].split('/api', 1)[0]
    return f"{base_url}/globalId/{response['globalId']}/"

# %%
rspace_url = r"https://rspace.ntnu.no/"
api_key = os.getenv("RSPACE_API_KEY")
client = ELNClient(rspace_url, api_key)

# %% [markdown]
# ## List documents
# Get information about the documents on RSpace. The returned value is a dictionary with lots of information as well as a _paginated_ list of document entires. The _paginated_ list is restricted to 20 entires by default (you can change this by supplying an argument to `client.get_documents()`). To get the other documents, you must make additional calls to `client.get_documents(page_number=i)`.

# %%
response = client.get_documents()
response
# Out:
# {'totalHits': 43,
#  'pageNumber': 0,
#  'documents': [{'id': 3556,
#    'globalId': 'SD3556',
#    'name': 'test',
#    'created': '2025-01-17T06:54:12.546Z',
#    'lastModified': '2025-01-17T07:06:48.958Z',
#    'parentFolderId': None,
#    'signed': False,
#    'tags': 'API',
#    'tagMetaData': None,
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3556',
#      'rel': 'self'}]},
#   {'id': 3554,
#    'globalId': 'SD3554',
#    'name': 'test',
#    'created': '2025-01-16T14:44:31.797Z',
#    'lastModified': '2025-01-16T14:44:32.038Z',
#    'parentFolderId': 2303,
#    'signed': False,
#    'tags': 'API',
#    'tagMetaData': 'API',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3554',
#      'rel': 'self'}]},
#   {'id': 3553,
#    'globalId': 'SD3553',
#    'name': 'Untitled document',
#    'created': '2025-01-16T14:30:07.192Z',
#    'lastModified': '2025-01-16T14:30:07.193Z',
#    'parentFolderId': 2303,
#    'signed': False,
#    'tags': None,
#    'tagMetaData': None,
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3553',
#      'rel': 'self'}]},
#   {'id': 3552,
#    'globalId': 'SD3552',
#    'name': 'Untitled document',
#    'created': '2025-01-16T14:29:28.863Z',
#    'lastModified': '2025-01-16T14:29:28.864Z',
#    'parentFolderId': 2303,
#    'signed': False,
#    'tags': None,
#    'tagMetaData': None,
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3552',
#      'rel': 'self'}]},
#   {'id': 3474,
#    'globalId': 'SD3474',
#    'name': 'example_experiment',
#    'created': '2024-12-13T10:12:04.091Z',
#    'lastModified': '2024-12-13T10:12:04.305Z',
#    'parentFolderId': 2303,
#    'signed': False,
#    'tags': 'API',
#    'tagMetaData': 'API',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3474',
#      'rel': 'self'}]},
#   {'id': 3466,
#    'globalId': 'SD3466',
#    'name': 'example_experiment',
#    'created': '2024-12-13T09:33:28.455Z',
#    'lastModified': '2024-12-13T09:33:28.676Z',
#    'parentFolderId': 2303,
#    'signed': False,
#    'tags': 'API',
#    'tagMetaData': 'API',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3466',
#      'rel': 'self'}]},
#   {'id': 3338,
#    'globalId': 'SD3338',
#    'name': 'Untitled document',
#    'created': '2024-12-06T09:27:42.217Z',
#    'lastModified': '2024-12-06T10:15:41.373Z',
#    'parentFolderId': 615,
#    'signed': False,
#    'tags': None,
#    'tagMetaData': None,
#    'form': {'id': 360455,
#     'globalId': 'FM360455',
#     'stableId': '1733475950535null',
#     'version': 0,
#     'name': 'SPED acquisition',
#     'tags': '',
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'READ',
#      'worldPermissionType': 'NONE'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3338',
#      'rel': 'self'}]},
#   {'id': 2921,
#    'globalId': 'SD2921',
#    'name': 'PicoScope measurements',
#    'created': '2024-11-22T11:00:46.333Z',
#    'lastModified': '2024-11-26T09:10:41.889Z',
#    'parentFolderId': 2920,
#    'signed': False,
#    'tags': 'P1000,NanoMegas',
#    'tagMetaData': 'P1000,NanoMegas',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2921',
#      'rel': 'self'}]},
#   {'id': 3124,
#    'globalId': 'SD3124',
#    'name': 'File delete from gallery',
#    'created': '2024-11-22T13:32:14.308Z',
#    'lastModified': '2024-11-22T13:40:20.225Z',
#    'parentFolderId': 3123,
#    'signed': False,
#    'tags': 'bug',
#    'tagMetaData': 'bug',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3124',
#      'rel': 'self'}]},
#   {'id': 2648,
#    'globalId': 'SD2648',
#    'name': 'example_experiment',
#    'created': '2024-11-12T13:17:29.998Z',
#    'lastModified': '2024-11-19T08:34:40.180Z',
#    'parentFolderId': None,
#    'signed': False,
#    'tags': 'API,SPED_Resolution',
#    'tagMetaData': None,
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2648',
#      'rel': 'self'}]},
#   {'id': 2868,
#    'globalId': 'SD2868',
#    'name': 'Untitled document',
#    'created': '2024-11-19T08:29:51.150Z',
#    'lastModified': '2024-11-19T08:29:51.152Z',
#    'parentFolderId': None,
#    'signed': False,
#    'tags': None,
#    'tagMetaData': None,
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 229399,
#     'username': 'magnunor@ntnu.no',
#     'email': 'magnus.nord@ntnu.no',
#     'firstName': 'Magnus',
#     'lastName': 'Nord',
#     'homeFolderId': 2042,
#     'workbenchId': None,
#     'hasPiRole': False,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2868',
#      'rel': 'self'}]},
#   {'id': 674,
#    'globalId': 'SD674',
#    'name': 'AA6060 T6 AC heat treatment',
#    'created': '2024-10-09T08:15:50.678Z',
#    'lastModified': '2024-11-12T12:34:04.570Z',
#    'parentFolderId': 654,
#    'signed': False,
#    'tags': 'T6,AA6060,AC',
#    'tagMetaData': 'T6,AA6060,AC',
#    'form': {'id': 294918,
#     'globalId': 'FM294918',
#     'stableId': '1728450179214null',
#     'version': 1,
#     'name': 'Heat treatment',
#     'tags': '',
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'READ',
#      'worldPermissionType': 'READ'},
#     'iconId': 38,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/674',
#      'rel': 'self'}]},
#   {'id': 2647,
#    'globalId': 'SD2647',
#    'name': 'Untitled document',
#    'created': '2024-11-12T12:28:06.757Z',
#    'lastModified': '2024-11-12T12:28:42.493Z',
#    'parentFolderId': 776,
#    'signed': False,
#    'tags': 'beam_energy=120',
#    'tagMetaData': 'beam_energy=120',
#    'form': {'id': 294918,
#     'globalId': 'FM294918',
#     'stableId': '1728450179214null',
#     'version': 1,
#     'name': 'Heat treatment',
#     'tags': '',
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'READ',
#      'worldPermissionType': 'READ'},
#     'iconId': 38,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2647',
#      'rel': 'self'}]},
#   {'id': 2632,
#    'globalId': 'SD2632',
#    'name': 'Untitled document',
#    'created': '2024-11-08T11:51:47.176Z',
#    'lastModified': '2024-11-08T11:52:02.460Z',
#    'parentFolderId': 776,
#    'signed': False,
#    'tags': 'Hei,beam_energy=200',
#    'tagMetaData': 'Hei,beam_energy=200',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2632',
#      'rel': 'self'}]},
#   {'id': 2594,
#    'globalId': 'SD2594',
#    'name': 'example_experiment',
#    'created': '2024-11-08T10:58:39.474Z',
#    'lastModified': '2024-11-08T10:58:39.777Z',
#    'parentFolderId': 1844,
#    'signed': False,
#    'tags': 'API,SPED_Resolution',
#    'tagMetaData': 'API,SPED_Resolution',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2594',
#      'rel': 'self'}]},
#   {'id': 2577,
#    'globalId': 'SD2577',
#    'name': 'example_experiment',
#    'created': '2024-11-08T07:43:57.800Z',
#    'lastModified': '2024-11-08T07:43:58.078Z',
#    'parentFolderId': 1844,
#    'signed': False,
#    'tags': 'API,SPED_Resolution',
#    'tagMetaData': 'API,SPED_Resolution',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2577',
#      'rel': 'self'}]},
#   {'id': 2364,
#    'globalId': 'SD2364',
#    'name': 'Untitled document',
#    'created': '2024-11-05T14:45:22.143Z',
#    'lastModified': '2024-11-06T11:24:35.754Z',
#    'parentFolderId': 1844,
#    'signed': False,
#    'tags': 'technique=SPED,instrument=2100F,mode=NBD,alpha=5,beam_energy=200',
#    'tagMetaData': 'technique=SPED,instrument=2100F,mode=NBD,alpha=5,beam_energy=200',
#    'form': {'id': 327744,
#     'globalId': 'FM327744',
#     'stableId': '1730817857017null',
#     'version': 0,
#     'name': 'SPED-experiment',
#     'tags': 'SPED',
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'READ',
#      'worldPermissionType': 'NONE'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2364',
#      'rel': 'self'}]},
#   {'id': 2378,
#    'globalId': 'SD2378',
#    'name': 'NORTEM ontologies',
#    'created': '2024-11-06T11:10:28.518Z',
#    'lastModified': '2024-11-06T11:18:10.658Z',
#    'parentFolderId': 651,
#    'signed': False,
#    'tags': None,
#    'tagMetaData': None,
#    'form': {'id': 2,
#     'globalId': 'FM2',
#     'stableId': '1724152243445null',
#     'version': 0,
#     'name': 'RSpace Tags from Ontologies',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': 6,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2378',
#      'rel': 'self'}]},
#   {'id': 2306,
#    'globalId': 'SD2306',
#    'name': 'Python API Example Basic Document',
#    'created': '2024-11-04T08:49:33.992Z',
#    'lastModified': '2024-11-04T08:58:21.705Z',
#    'parentFolderId': 2303,
#    'signed': False,
#    'tags': 'Python,API,example,TESt,Test,TEst,TEST,test,Hei,På,Deg,tes,2,2',
#    'tagMetaData': 'Python,API,example,TESt,Test,TEst,TEST,test,Hei,På,Deg,tes,2,2',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2306',
#      'rel': 'self'}]},
#   {'id': 2304,
#    'globalId': 'SD2304',
#    'name': 'Python API Example Basic Document',
#    'created': '2024-11-04T08:32:07.080Z',
#    'lastModified': '2024-11-04T08:49:00.957Z',
#    'parentFolderId': 2303,
#    'signed': False,
#    'tags': 'TESt',
#    'tagMetaData': 'TESt',
#    'form': {'id': 65536,
#     'globalId': 'FM65536',
#     'stableId': '1724164328846null',
#     'version': 0,
#     'name': 'Basic Document',
#     'tags': None,
#     'formState': 'PUBLISHED',
#     'accessControl': {'ownerPermissionType': 'WRITE',
#      'groupPermissionType': 'NONE',
#      'worldPermissionType': 'READ'},
#     'iconId': -1,
#     '_links': []},
#    'owner': {'id': 196610,
#     'username': 'emilc@ntnu.no',
#     'email': 'emil.christiansen@ntnu.no',
#     'firstName': 'Emil Frang',
#     'lastName': 'Christiansen',
#     'homeFolderId': 615,
#     'workbenchId': None,
#     'hasPiRole': True,
#     'hasSysAdminRole': False,
#     '_links': []},
#    '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2304',
#      'rel': 'self'}]}],
#  '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents?pageNumber=1',
#    'rel': 'next'},
#   {'link': 'https://rspace.ntnu.no/api/v1/documents?pageNumber=2',
#    'rel': 'last'},
#   {'link': 'https://rspace.ntnu.no/api/v1/documents?pageNumber=0',
#    'rel': 'self'}]}

# %%
print(f"Found {response['totalHits']} documents on RSpace. The response contains information about {len(response['documents'])} documents. To see information about more documents, run `client.get_documents(page_number=i)` with `i>0`.")
_ = [print(document['id'], document['name']) for document in response['documents']]
# Out:
# Found 43 documents on RSpace. The response contains information about 20 documents. To see information about more documents, run `client.get_documents(page_number=i)` with `i>0`.
# 3556 test
# 3554 test
# 3553 Untitled document
# 3552 Untitled document
# 3474 example_experiment
# 3466 example_experiment
# 3338 Untitled document
# 2921 PicoScope measurements
# 3124 File delete from gallery
# 2648 example_experiment
# 2868 Untitled document
# 674 AA6060 T6 AC heat treatment
# 2647 Untitled document
# 2632 Untitled document
# 2594 example_experiment
# 2577 example_experiment
# 2364 Untitled document
# 2378 NORTEM ontologies
# 2306 Python API Example Basic Document
# 2304 Python API Example Basic Document

# %% [markdown]
# To get all the documents on RSpace, we need to make consecutive calls to `client.get_documents()` with increasing page_numbers. One way to do this without knowing how many pages we expect there are, is to run an infinite loop that we break once the response stops returning any documents

# %%
documents = []
i = 0
while True:
    response = client.get_documents(page_number=i)
    if len(response["documents"]) == 0:
        break
    documents += response["documents"]
    i += 1
documents
# Out:
# [{'id': 3556,
#   'globalId': 'SD3556',
#   'name': 'test',
#   'created': '2025-01-17T06:54:12.546Z',
#   'lastModified': '2025-01-17T07:06:48.958Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'API',
#   'tagMetaData': None,
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3556',
#     'rel': 'self'}]},
#  {'id': 3554,
#   'globalId': 'SD3554',
#   'name': 'test',
#   'created': '2025-01-16T14:44:31.797Z',
#   'lastModified': '2025-01-16T14:44:32.038Z',
#   'parentFolderId': 2303,
#   'signed': False,
#   'tags': 'API',
#   'tagMetaData': 'API',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3554',
#     'rel': 'self'}]},
#  {'id': 3553,
#   'globalId': 'SD3553',
#   'name': 'Untitled document',
#   'created': '2025-01-16T14:30:07.192Z',
#   'lastModified': '2025-01-16T14:30:07.193Z',
#   'parentFolderId': 2303,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3553',
#     'rel': 'self'}]},
#  {'id': 3552,
#   'globalId': 'SD3552',
#   'name': 'Untitled document',
#   'created': '2025-01-16T14:29:28.863Z',
#   'lastModified': '2025-01-16T14:29:28.864Z',
#   'parentFolderId': 2303,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3552',
#     'rel': 'self'}]},
#  {'id': 3474,
#   'globalId': 'SD3474',
#   'name': 'example_experiment',
#   'created': '2024-12-13T10:12:04.091Z',
#   'lastModified': '2024-12-13T10:12:04.305Z',
#   'parentFolderId': 2303,
#   'signed': False,
#   'tags': 'API',
#   'tagMetaData': 'API',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3474',
#     'rel': 'self'}]},
#  {'id': 3466,
#   'globalId': 'SD3466',
#   'name': 'example_experiment',
#   'created': '2024-12-13T09:33:28.455Z',
#   'lastModified': '2024-12-13T09:33:28.676Z',
#   'parentFolderId': 2303,
#   'signed': False,
#   'tags': 'API',
#   'tagMetaData': 'API',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3466',
#     'rel': 'self'}]},
#  {'id': 3338,
#   'globalId': 'SD3338',
#   'name': 'Untitled document',
#   'created': '2024-12-06T09:27:42.217Z',
#   'lastModified': '2024-12-06T10:15:41.373Z',
#   'parentFolderId': 615,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 360455,
#    'globalId': 'FM360455',
#    'stableId': '1733475950535null',
#    'version': 0,
#    'name': 'SPED acquisition',
#    'tags': '',
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'READ',
#     'worldPermissionType': 'NONE'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3338',
#     'rel': 'self'}]},
#  {'id': 2921,
#   'globalId': 'SD2921',
#   'name': 'PicoScope measurements',
#   'created': '2024-11-22T11:00:46.333Z',
#   'lastModified': '2024-11-26T09:10:41.889Z',
#   'parentFolderId': 2920,
#   'signed': False,
#   'tags': 'P1000,NanoMegas',
#   'tagMetaData': 'P1000,NanoMegas',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2921',
#     'rel': 'self'}]},
#  {'id': 3124,
#   'globalId': 'SD3124',
#   'name': 'File delete from gallery',
#   'created': '2024-11-22T13:32:14.308Z',
#   'lastModified': '2024-11-22T13:40:20.225Z',
#   'parentFolderId': 3123,
#   'signed': False,
#   'tags': 'bug',
#   'tagMetaData': 'bug',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3124',
#     'rel': 'self'}]},
#  {'id': 2648,
#   'globalId': 'SD2648',
#   'name': 'example_experiment',
#   'created': '2024-11-12T13:17:29.998Z',
#   'lastModified': '2024-11-19T08:34:40.180Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'API,SPED_Resolution',
#   'tagMetaData': None,
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2648',
#     'rel': 'self'}]},
#  {'id': 2868,
#   'globalId': 'SD2868',
#   'name': 'Untitled document',
#   'created': '2024-11-19T08:29:51.150Z',
#   'lastModified': '2024-11-19T08:29:51.152Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 229399,
#    'username': 'magnunor@ntnu.no',
#    'email': 'magnus.nord@ntnu.no',
#    'firstName': 'Magnus',
#    'lastName': 'Nord',
#    'homeFolderId': 2042,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2868',
#     'rel': 'self'}]},
#  {'id': 674,
#   'globalId': 'SD674',
#   'name': 'AA6060 T6 AC heat treatment',
#   'created': '2024-10-09T08:15:50.678Z',
#   'lastModified': '2024-11-12T12:34:04.570Z',
#   'parentFolderId': 654,
#   'signed': False,
#   'tags': 'T6,AA6060,AC',
#   'tagMetaData': 'T6,AA6060,AC',
#   'form': {'id': 294918,
#    'globalId': 'FM294918',
#    'stableId': '1728450179214null',
#    'version': 1,
#    'name': 'Heat treatment',
#    'tags': '',
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'READ',
#     'worldPermissionType': 'READ'},
#    'iconId': 38,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/674',
#     'rel': 'self'}]},
#  {'id': 2647,
#   'globalId': 'SD2647',
#   'name': 'Untitled document',
#   'created': '2024-11-12T12:28:06.757Z',
#   'lastModified': '2024-11-12T12:28:42.493Z',
#   'parentFolderId': 776,
#   'signed': False,
#   'tags': 'beam_energy=120',
#   'tagMetaData': 'beam_energy=120',
#   'form': {'id': 294918,
#    'globalId': 'FM294918',
#    'stableId': '1728450179214null',
#    'version': 1,
#    'name': 'Heat treatment',
#    'tags': '',
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'READ',
#     'worldPermissionType': 'READ'},
#    'iconId': 38,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2647',
#     'rel': 'self'}]},
#  {'id': 2632,
#   'globalId': 'SD2632',
#   'name': 'Untitled document',
#   'created': '2024-11-08T11:51:47.176Z',
#   'lastModified': '2024-11-08T11:52:02.460Z',
#   'parentFolderId': 776,
#   'signed': False,
#   'tags': 'Hei,beam_energy=200',
#   'tagMetaData': 'Hei,beam_energy=200',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2632',
#     'rel': 'self'}]},
#  {'id': 2594,
#   'globalId': 'SD2594',
#   'name': 'example_experiment',
#   'created': '2024-11-08T10:58:39.474Z',
#   'lastModified': '2024-11-08T10:58:39.777Z',
#   'parentFolderId': 1844,
#   'signed': False,
#   'tags': 'API,SPED_Resolution',
#   'tagMetaData': 'API,SPED_Resolution',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2594',
#     'rel': 'self'}]},
#  {'id': 2577,
#   'globalId': 'SD2577',
#   'name': 'example_experiment',
#   'created': '2024-11-08T07:43:57.800Z',
#   'lastModified': '2024-11-08T07:43:58.078Z',
#   'parentFolderId': 1844,
#   'signed': False,
#   'tags': 'API,SPED_Resolution',
#   'tagMetaData': 'API,SPED_Resolution',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2577',
#     'rel': 'self'}]},
#  {'id': 2364,
#   'globalId': 'SD2364',
#   'name': 'Untitled document',
#   'created': '2024-11-05T14:45:22.143Z',
#   'lastModified': '2024-11-06T11:24:35.754Z',
#   'parentFolderId': 1844,
#   'signed': False,
#   'tags': 'technique=SPED,instrument=2100F,mode=NBD,alpha=5,beam_energy=200',
#   'tagMetaData': 'technique=SPED,instrument=2100F,mode=NBD,alpha=5,beam_energy=200',
#   'form': {'id': 327744,
#    'globalId': 'FM327744',
#    'stableId': '1730817857017null',
#    'version': 0,
#    'name': 'SPED-experiment',
#    'tags': 'SPED',
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'READ',
#     'worldPermissionType': 'NONE'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2364',
#     'rel': 'self'}]},
#  {'id': 2378,
#   'globalId': 'SD2378',
#   'name': 'NORTEM ontologies',
#   'created': '2024-11-06T11:10:28.518Z',
#   'lastModified': '2024-11-06T11:18:10.658Z',
#   'parentFolderId': 651,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 2,
#    'globalId': 'FM2',
#    'stableId': '1724152243445null',
#    'version': 0,
#    'name': 'RSpace Tags from Ontologies',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 6,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2378',
#     'rel': 'self'}]},
#  {'id': 2306,
#   'globalId': 'SD2306',
#   'name': 'Python API Example Basic Document',
#   'created': '2024-11-04T08:49:33.992Z',
#   'lastModified': '2024-11-04T08:58:21.705Z',
#   'parentFolderId': 2303,
#   'signed': False,
#   'tags': 'Python,API,example,TESt,Test,TEst,TEST,test,Hei,På,Deg,tes,2,2',
#   'tagMetaData': 'Python,API,example,TESt,Test,TEst,TEST,test,Hei,På,Deg,tes,2,2',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2306',
#     'rel': 'self'}]},
#  {'id': 2304,
#   'globalId': 'SD2304',
#   'name': 'Python API Example Basic Document',
#   'created': '2024-11-04T08:32:07.080Z',
#   'lastModified': '2024-11-04T08:49:00.957Z',
#   'parentFolderId': 2303,
#   'signed': False,
#   'tags': 'TESt',
#   'tagMetaData': 'TESt',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2304',
#     'rel': 'self'}]},
#  {'id': 2231,
#   'globalId': 'SD2231',
#   'name': 'SJHP3 ELISA',
#   'created': '2024-10-30T15:12:48.532Z',
#   'lastModified': '2024-10-30T15:12:48.538Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65540,
#    'globalId': 'FM65540',
#    'stableId': '1724164328967null',
#    'version': 0,
#    'name': 'ELISA',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 25,
#    '_links': []},
#   'owner': {'id': 229405,
#    'username': 'mosberg@ntnu.no',
#    'email': 'aleksander.b.mosberg@ntnu.no',
#    'firstName': 'Aleksander Buseth',
#    'lastName': 'Mosberg',
#    'homeFolderId': 2204,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2231',
#     'rel': 'self'}]},
#  {'id': 2229,
#   'globalId': 'SD2229',
#   'name': 'bam mutant rtPCR',
#   'created': '2024-10-30T15:12:48.440Z',
#   'lastModified': '2024-10-30T15:12:48.531Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65539,
#    'globalId': 'FM65539',
#    'stableId': '1724164328950null',
#    'version': 0,
#    'name': 'rtPCR',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 24,
#    '_links': []},
#   'owner': {'id': 229405,
#    'username': 'mosberg@ntnu.no',
#    'email': 'aleksander.b.mosberg@ntnu.no',
#    'firstName': 'Aleksander Buseth',
#    'lastName': 'Mosberg',
#    'homeFolderId': 2204,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2229',
#     'rel': 'self'}]},
#  {'id': 2226,
#   'globalId': 'SD2226',
#   'name': 'Sensitivity of Cancer cell line XYZ to Drug A',
#   'created': '2024-10-30T15:12:48.189Z',
#   'lastModified': '2024-10-30T15:12:48.439Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'exampleExperimentTag',
#   'tagMetaData': None,
#   'form': {'id': 65538,
#    'globalId': 'FM65538',
#    'stableId': '1724164328935null',
#    'version': 0,
#    'name': 'Experiment',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 23,
#    '_links': []},
#   'owner': {'id': 229405,
#    'username': 'mosberg@ntnu.no',
#    'email': 'aleksander.b.mosberg@ntnu.no',
#    'firstName': 'Aleksander Buseth',
#    'lastName': 'Mosberg',
#    'homeFolderId': 2204,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2226',
#     'rel': 'self'}]},
#  {'id': 2225,
#   'globalId': 'SD2225',
#   'name': 'Extract Protocol for ChIP',
#   'created': '2024-10-30T15:12:48.171Z',
#   'lastModified': '2024-10-30T15:12:48.172Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65537,
#    'globalId': 'FM65537',
#    'stableId': '1724164328865null',
#    'version': 0,
#    'name': 'Lab Protocol',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 22,
#    '_links': []},
#   'owner': {'id': 229405,
#    'username': 'mosberg@ntnu.no',
#    'email': 'aleksander.b.mosberg@ntnu.no',
#    'firstName': 'Aleksander Buseth',
#    'lastName': 'Mosberg',
#    'homeFolderId': 2204,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2225',
#     'rel': 'self'}]},
#  {'id': 2069,
#   'globalId': 'SD2069',
#   'name': 'SJHP3 ELISA',
#   'created': '2024-10-30T13:25:39.878Z',
#   'lastModified': '2024-10-30T13:25:39.884Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65540,
#    'globalId': 'FM65540',
#    'stableId': '1724164328967null',
#    'version': 0,
#    'name': 'ELISA',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 25,
#    '_links': []},
#   'owner': {'id': 229399,
#    'username': 'magnunor@ntnu.no',
#    'email': 'magnus.nord@ntnu.no',
#    'firstName': 'Magnus',
#    'lastName': 'Nord',
#    'homeFolderId': 2042,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2069',
#     'rel': 'self'}]},
#  {'id': 2067,
#   'globalId': 'SD2067',
#   'name': 'bam mutant rtPCR',
#   'created': '2024-10-30T13:25:39.809Z',
#   'lastModified': '2024-10-30T13:25:39.877Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65539,
#    'globalId': 'FM65539',
#    'stableId': '1724164328950null',
#    'version': 0,
#    'name': 'rtPCR',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 24,
#    '_links': []},
#   'owner': {'id': 229399,
#    'username': 'magnunor@ntnu.no',
#    'email': 'magnus.nord@ntnu.no',
#    'firstName': 'Magnus',
#    'lastName': 'Nord',
#    'homeFolderId': 2042,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2067',
#     'rel': 'self'}]},
#  {'id': 2064,
#   'globalId': 'SD2064',
#   'name': 'Sensitivity of Cancer cell line XYZ to Drug A',
#   'created': '2024-10-30T13:25:39.639Z',
#   'lastModified': '2024-10-30T13:25:39.808Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'exampleExperimentTag',
#   'tagMetaData': None,
#   'form': {'id': 65538,
#    'globalId': 'FM65538',
#    'stableId': '1724164328935null',
#    'version': 0,
#    'name': 'Experiment',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 23,
#    '_links': []},
#   'owner': {'id': 229399,
#    'username': 'magnunor@ntnu.no',
#    'email': 'magnus.nord@ntnu.no',
#    'firstName': 'Magnus',
#    'lastName': 'Nord',
#    'homeFolderId': 2042,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2064',
#     'rel': 'self'}]},
#  {'id': 2063,
#   'globalId': 'SD2063',
#   'name': 'Extract Protocol for ChIP',
#   'created': '2024-10-30T13:25:39.631Z',
#   'lastModified': '2024-10-30T13:25:39.632Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65537,
#    'globalId': 'FM65537',
#    'stableId': '1724164328865null',
#    'version': 0,
#    'name': 'Lab Protocol',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 22,
#    '_links': []},
#   'owner': {'id': 229399,
#    'username': 'magnunor@ntnu.no',
#    'email': 'magnus.nord@ntnu.no',
#    'firstName': 'Magnus',
#    'lastName': 'Nord',
#    'homeFolderId': 2042,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2063',
#     'rel': 'self'}]},
#  {'id': 1846,
#   'globalId': 'SD1846',
#   'name': 'SPED data aquisition',
#   'created': '2024-10-28T09:00:16.270Z',
#   'lastModified': '2024-10-28T09:20:08.742Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'SPED,reolsution',
#   'tagMetaData': None,
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/1846',
#     'rel': 'self'}]},
#  {'id': 1845,
#   'globalId': 'SD1845',
#   'name': 'SPED data aquisition',
#   'created': '2024-10-28T08:59:14.984Z',
#   'lastModified': '2024-10-28T08:59:45.132Z',
#   'parentFolderId': 1844,
#   'signed': False,
#   'tags': 'SPED,reolsution',
#   'tagMetaData': 'SPED,reolsution',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/1845',
#     'rel': 'self'}]},
#  {'id': 779,
#   'globalId': 'SD779',
#   'name': 'Goniometer characterization',
#   'created': '2024-10-11T12:01:07.526Z',
#   'lastModified': '2024-10-11T12:17:06.277Z',
#   'parentFolderId': 778,
#   'signed': False,
#   'tags': 'cRED,Si',
#   'tagMetaData': 'cRED,Si',
#   'form': {'id': 65536,
#    'globalId': 'FM65536',
#    'stableId': '1724164328846null',
#    'version': 0,
#    'name': 'Basic Document',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': -1,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/779',
#     'rel': 'self'}]},
#  {'id': 671,
#   'globalId': 'SD671',
#   'name': 'AA6060 T6 WQ heat treatment',
#   'created': '2024-10-09T08:13:08.969Z',
#   'lastModified': '2024-10-09T11:41:45.794Z',
#   'parentFolderId': 654,
#   'signed': False,
#   'tags': 'T6 AA6060,WQ',
#   'tagMetaData': 'T6 AA6060,WQ',
#   'form': {'id': 294918,
#    'globalId': 'FM294918',
#    'stableId': '1728450179214null',
#    'version': 1,
#    'name': 'Heat treatment',
#    'tags': '',
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'READ',
#     'worldPermissionType': 'READ'},
#    'iconId': 38,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/671',
#     'rel': 'self'}]},
#  {'id': 652,
#   'globalId': 'SD652',
#   'name': 'YOUR_AUTOGENERATED_TAGS.ontology',
#   'created': '2024-10-08T14:14:10.002Z',
#   'lastModified': '2024-10-08T14:14:10.027Z',
#   'parentFolderId': 651,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 2,
#    'globalId': 'FM2',
#    'stableId': '1724152243445null',
#    'version': 0,
#    'name': 'RSpace Tags from Ontologies',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 6,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/652',
#     'rel': 'self'}]},
#  {'id': 642,
#   'globalId': 'SD642',
#   'name': 'SJHP3 ELISA',
#   'created': '2024-10-08T10:46:15.469Z',
#   'lastModified': '2024-10-08T10:46:15.479Z',
#   'parentFolderId': 620,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65540,
#    'globalId': 'FM65540',
#    'stableId': '1724164328967null',
#    'version': 0,
#    'name': 'ELISA',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 25,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/642',
#     'rel': 'self'}]},
#  {'id': 640,
#   'globalId': 'SD640',
#   'name': 'bam mutant rtPCR',
#   'created': '2024-10-08T10:46:15.341Z',
#   'lastModified': '2024-10-08T10:46:15.466Z',
#   'parentFolderId': 620,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65539,
#    'globalId': 'FM65539',
#    'stableId': '1724164328950null',
#    'version': 0,
#    'name': 'rtPCR',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 24,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/640',
#     'rel': 'self'}]},
#  {'id': 637,
#   'globalId': 'SD637',
#   'name': 'Sensitivity of Cancer cell line XYZ to Drug A',
#   'created': '2024-10-08T10:46:15.044Z',
#   'lastModified': '2024-10-08T10:46:15.338Z',
#   'parentFolderId': 620,
#   'signed': False,
#   'tags': 'exampleExperimentTag',
#   'tagMetaData': None,
#   'form': {'id': 65538,
#    'globalId': 'FM65538',
#    'stableId': '1724164328935null',
#    'version': 0,
#    'name': 'Experiment',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 23,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/637',
#     'rel': 'self'}]},
#  {'id': 636,
#   'globalId': 'SD636',
#   'name': 'Extract Protocol for ChIP',
#   'created': '2024-10-08T10:46:15.018Z',
#   'lastModified': '2024-10-08T10:46:15.019Z',
#   'parentFolderId': 620,
#   'signed': False,
#   'tags': None,
#   'tagMetaData': None,
#   'form': {'id': 65537,
#    'globalId': 'FM65537',
#    'stableId': '1724164328865null',
#    'version': 0,
#    'name': 'Lab Protocol',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'READ'},
#    'iconId': 22,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/636',
#     'rel': 'self'}]},
#  {'id': 2237,
#   'globalId': 'SD2237',
#   'name': 'Ethane',
#   'created': '2019-02-12T19:51:44.000Z',
#   'lastModified': '2019-02-12T19:51:45.120Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'chemical',
#   'tagMetaData': 'chemical',
#   'form': {'id': 327718,
#    'globalId': 'FM327718',
#    'stableId': '1730301168645null',
#    'version': 2,
#    'name': 'chemical data sheet',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'NONE'},
#    'iconId': 78,
#    '_links': []},
#   'owner': {'id': 229405,
#    'username': 'mosberg@ntnu.no',
#    'email': 'aleksander.b.mosberg@ntnu.no',
#    'firstName': 'Aleksander Buseth',
#    'lastName': 'Mosberg',
#    'homeFolderId': 2204,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2237',
#     'rel': 'self'}]},
#  {'id': 2075,
#   'globalId': 'SD2075',
#   'name': 'Ethane',
#   'created': '2019-02-12T19:51:44.000Z',
#   'lastModified': '2019-02-12T19:51:45.120Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'chemical',
#   'tagMetaData': 'chemical',
#   'form': {'id': 327713,
#    'globalId': 'FM327713',
#    'stableId': '1730294739995null',
#    'version': 2,
#    'name': 'chemical data sheet',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'NONE'},
#    'iconId': 74,
#    '_links': []},
#   'owner': {'id': 229399,
#    'username': 'magnunor@ntnu.no',
#    'email': 'magnus.nord@ntnu.no',
#    'firstName': 'Magnus',
#    'lastName': 'Nord',
#    'homeFolderId': 2042,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2075',
#     'rel': 'self'}]},
#  {'id': 648,
#   'globalId': 'SD648',
#   'name': 'Ethane',
#   'created': '2019-02-12T19:51:44.000Z',
#   'lastModified': '2019-02-12T19:51:45.120Z',
#   'parentFolderId': 644,
#   'signed': False,
#   'tags': 'chemical',
#   'tagMetaData': 'chemical',
#   'form': {'id': 294914,
#    'globalId': 'FM294914',
#    'stableId': '1728384375687null',
#    'version': 2,
#    'name': 'chemical data sheet',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'NONE'},
#    'iconId': 37,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/648',
#     'rel': 'self'}]},
#  {'id': 2234,
#   'globalId': 'SD2234',
#   'name': '2,4,6-Trichloropyrimidine',
#   'created': '2019-02-12T19:51:38.000Z',
#   'lastModified': '2019-02-12T19:51:44.193Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'chemical',
#   'tagMetaData': 'chemical',
#   'form': {'id': 327718,
#    'globalId': 'FM327718',
#    'stableId': '1730301168645null',
#    'version': 2,
#    'name': 'chemical data sheet',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'NONE'},
#    'iconId': 78,
#    '_links': []},
#   'owner': {'id': 229405,
#    'username': 'mosberg@ntnu.no',
#    'email': 'aleksander.b.mosberg@ntnu.no',
#    'firstName': 'Aleksander Buseth',
#    'lastName': 'Mosberg',
#    'homeFolderId': 2204,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2234',
#     'rel': 'self'}]},
#  {'id': 2072,
#   'globalId': 'SD2072',
#   'name': '2,4,6-Trichloropyrimidine',
#   'created': '2019-02-12T19:51:38.000Z',
#   'lastModified': '2019-02-12T19:51:44.193Z',
#   'parentFolderId': None,
#   'signed': False,
#   'tags': 'chemical',
#   'tagMetaData': 'chemical',
#   'form': {'id': 327713,
#    'globalId': 'FM327713',
#    'stableId': '1730294739995null',
#    'version': 2,
#    'name': 'chemical data sheet',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'NONE'},
#    'iconId': 74,
#    '_links': []},
#   'owner': {'id': 229399,
#    'username': 'magnunor@ntnu.no',
#    'email': 'magnus.nord@ntnu.no',
#    'firstName': 'Magnus',
#    'lastName': 'Nord',
#    'homeFolderId': 2042,
#    'workbenchId': None,
#    'hasPiRole': False,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/2072',
#     'rel': 'self'}]},
#  {'id': 645,
#   'globalId': 'SD645',
#   'name': '2,4,6-Trichloropyrimidine',
#   'created': '2019-02-12T19:51:38.000Z',
#   'lastModified': '2019-02-12T19:51:44.193Z',
#   'parentFolderId': 644,
#   'signed': False,
#   'tags': 'chemical',
#   'tagMetaData': 'chemical',
#   'form': {'id': 294914,
#    'globalId': 'FM294914',
#    'stableId': '1728384375687null',
#    'version': 2,
#    'name': 'chemical data sheet',
#    'tags': None,
#    'formState': 'PUBLISHED',
#    'accessControl': {'ownerPermissionType': 'WRITE',
#     'groupPermissionType': 'NONE',
#     'worldPermissionType': 'NONE'},
#    'iconId': 37,
#    '_links': []},
#   'owner': {'id': 196610,
#    'username': 'emilc@ntnu.no',
#    'email': 'emil.christiansen@ntnu.no',
#    'firstName': 'Emil Frang',
#    'lastName': 'Christiansen',
#    'homeFolderId': 615,
#    'workbenchId': None,
#    'hasPiRole': True,
#    'hasSysAdminRole': False,
#    '_links': []},
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/645',
#     'rel': 'self'}]}]

# %% [markdown]
# We can also create a table with the document IDs and the titles to format it a little nicer than before.

# %%
table = tabulate([[document['id'], document['name']] for document in documents], ['ID', 'Title'])

print(table)
# Out:
#   ID  Title
# ----  ---------------------------------------------
# 3556  test
# 3554  test
# 3553  Untitled document
# 3552  Untitled document
# 3474  example_experiment
# 3466  example_experiment
# 3338  Untitled document
# 2921  PicoScope measurements
# 3124  File delete from gallery
# 2648  example_experiment
# 2868  Untitled document
#  674  AA6060 T6 AC heat treatment
# 2647  Untitled document
# 2632  Untitled document
# 2594  example_experiment
# 2577  example_experiment
# 2364  Untitled document
# 2378  NORTEM ontologies
# 2306  Python API Example Basic Document
# 2304  Python API Example Basic Document
# 2231  SJHP3 ELISA
# 2229  bam mutant rtPCR
# 2226  Sensitivity of Cancer cell line XYZ to Drug A
# 2225  Extract Protocol for ChIP
# 2069  SJHP3 ELISA
# 2067  bam mutant rtPCR
# 2064  Sensitivity of Cancer cell line XYZ to Drug A
# 2063  Extract Protocol for ChIP
# 1846  SPED data aquisition
# 1845  SPED data aquisition
#  779  Goniometer characterization
#  671  AA6060 T6 WQ heat treatment
#  652  YOUR_AUTOGENERATED_TAGS.ontology
#  642  SJHP3 ELISA
#  640  bam mutant rtPCR
#  637  Sensitivity of Cancer cell line XYZ to Drug A
#  636  Extract Protocol for ChIP
# 2237  Ethane
# 2075  Ethane
#  648  Ethane
# 2234  2,4,6-Trichloropyrimidine
# 2072  2,4,6-Trichloropyrimidine
#  645  2,4,6-Trichloropyrimidine

# %% [markdown]
# ## Create a document with the API
#
# You can also create documents on RSpace through the API with the `client.create_document()` call. All documents on RSpace are actually _forms_. A _form_ is a group or collection of _fields_ that can hold information. This means that when creating a document you will need to specify which _field_ you want to put various pieces of information. Let us first try to create a simple basic document with some text.

# %%
text = "<h1>RSpace API example text</h1>\nThis is a very useful document <h2>It can have various header levels</h2>\nIf you write some HTML syntax in here, it will be nicely formatted once it goes on RSpace."

response = client.create_document(name="Test", parent_folder_id=None, tags=["API", "Test"], fields=[{"content": text}])

print(f"Created document with ID {response['id']}")
# Out:
# Created document with ID 3559

# %% [markdown]
# If you go to RSpace you will now be able to find a document with the ID printed above. You can now edit the document on RSpace directly, or continue working on it through the API

# %% [markdown]
# ## Do some analysis and update the document

# %%
output_file = Path("test.png")
x = np.arange(0, 4*np.pi, 0.1)
y = np.sin(x)
fig, ax = plt.subplots()
ax.plot(x, y)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('Sine wave')
fig.savefig("test.png")

with output_file.open('rb') as f:
    upload_response = client.upload_file(f, caption="API Test")
print(f"Uploaded image with ID {upload_response['id']}")
# Out:
# <div id='eeb67075-20a8-4012-9a1c-f7ae7f396e01'></div>
# Uploaded image with ID 3562

# %%
content = f"""
<h2>Example of python analysis</h2>
<p>Plot of a sine wave between {x[0]} and {x[-1]}: <fileId={upload_response['id']}></p>
"""

updated_doc = client.append_content(response['id'], content)

print(f"Updated document ({updated_doc['id']}). You can view the document here: {get_url_link(updated_doc)}")
# Out:
# Updated document (3559. You can view the document here: https://rspace.ntnu.no/globalId/SD3559/

# %% [markdown]
# ## Get files from a document and do some changes
#
# First, let us download all the files attatched to the document we just created. If you ran parts of the code earlier several times, you might end up with more than one file.

# %%
document = client.get_document(updated_doc['id'])
for field in document['fields']:
    files = field.get('files')
    print(f'Field {field["name"]} refers to {len(files)} file(s):')
    for file in files:
        print(f"\t{file['id']}\t{file['globalId']}\t{file['name']}\t{get_url_link(file)}.")
    print(f"Downloading files...")
    downloaded_files = []
    for file in files:
        path = Path(f"{file['id']}_{file['name']}")
        print(f"\tDownloading {file['name']}({file['id']}) to {path.absolute()}...")
        client.download_file(file['id'], path.absolute())
        print(f"\t\tFinished downloading file.")
        downloaded_files.append(path)
# Out:
# Field Data refers to 1 file(s):
# 	3562	GL3562	test.png	https://rspace.ntnu.no/globalId/GL3562/.
# Downloading files...
# 	Downloading test.png(3562) to C:\Users\emilc\LocalDocuments\GitHub\RSpaceNORTEM\rspace\notebooks\3562_test.png...
# 		Finished downloading file.

# %% [markdown]
# Next, let us read the .png images back into Python and do some cosmetic changes that does not make sense at all, but serves to show how you can work with data you have already put on RSpace and upload new versions of the files.

# %%
for file in downloaded_files:
    im = plt.imread(file.absolute())
    modified_image = im.copy()
    modified_image[:, :, 3] = 0.5 #Set opacity to 50%
    modified_image[:, :, 2] = 0 #Set blue channel to 0
    fig, ax = plt.subplots(nrows=1, ncols=2)
    ax[0].imshow(im)
    ax[0].set_title('Original')
    ax[1].imshow(modified_image)
    ax[1].set_title('Modified image')
    fig.suptitle("Modified image comparison")
    plt.tight_layout()
    
    modified_file = file.with_stem(f"{file.stem}_modified")
    fig.savefig(modified_file)
    
    file_id = file.stem.split('_')[0] #file ID is stored in file path. There are more elegant ways to do this....
    
    with modified_file.open('rb') as f:
        updated_file = client.update_file(f, file_id)
    
    print(f"Updated file {updated_file['name']} ({updated_file['id']}). No changes are required in the original document!")
# Out:
# 3562_test.png
# <div id='5e84e89b-4c66-450f-92ba-34c2704c70d5'></div>
# Updated file 3562_test_modified.png(3562). No changes are required in the original document!

# %% [markdown]
# We can also do changes to the text. However, this is not very convenient unless you are working with forms with well-defined fields. For our basic document, for now let us make all the text italic.

# %%
content = "<em>" + client.get_document(document['id'])['fields'][0]['content'] + "</em>"
client.update_document(document['id'], fields=[{"content": content}])
# Out:
# {'id': 3559,
#  'globalId': 'SD3559',
#  'name': 'Test',
#  'created': '2025-01-17T15:15:28.452Z',
#  'lastModified': '2025-01-18T12:43:46.894Z',
#  'parentFolderId': 2303,
#  'signed': False,
#  'tags': 'API,Test',
#  'tagMetaData': 'API,Test',
#  'form': {'id': 65536,
#   'globalId': 'FM65536',
#   'stableId': '1724164328846null',
#   'version': 0,
#   'name': 'Basic Document',
#   'tags': None,
#   'formState': 'PUBLISHED',
#   'accessControl': {'ownerPermissionType': 'WRITE',
#    'groupPermissionType': 'NONE',
#    'worldPermissionType': 'READ'},
#   'iconId': -1,
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/forms/65536',
#     'rel': 'self'}]},
#  'owner': {'id': 196610,
#   'username': 'emilc@ntnu.no',
#   'email': 'emil.christiansen@ntnu.no',
#   'firstName': 'Emil Frang',
#   'lastName': 'Christiansen',
#   'homeFolderId': 615,
#   'workbenchId': None,
#   'hasPiRole': True,
#   'hasSysAdminRole': False,
#   '_links': []},
#  'fields': [{'id': 393277,
#    'globalId': 'FD393277',
#    'name': 'Data',
#    'type': 'text',
#    'content': '<em><h1>RSpace API example text</h1> This is a very useful document <h2>It can have various header levels</h2> If you write some HTML syntax in here, it will be nicely formatted once it goes on RSpace. <h2>Example of python analysis</h2> <p>Plot of a sine wave between 0.0 and 12.5: =3562</p> <h2>Example of python analysis</h2> <p>Plot of a sine wave between 0.0 and 12.5:</p> <p><img id="393277-3562" class="imageDropped inlineImageThumbnail" src="/thumbnail/data?sourceType=IMAGE&amp;sourceId=3562&amp;sourceParentId=393277&amp;width=640&amp;height=480&amp;rotation=0&amp;time=1737127576101&amp;revision=2593" alt="image test.png" width="640" height="480" data-size="640-480" data-rotation="0" data-rsrevision="2593" /></p>&nbsp; <p></p> <h2>Example of python analysis</h2> <p>Plot of a sine wave between 0.0 and 12.5:</p> <p><img id="393277-3562" class="imageDropped inlineImageThumbnail" src="/thumbnail/data?sourceType=IMAGE&amp;sourceId=3562&amp;sourceParentId=393277&amp;width=640&amp;height=480&amp;rotation=0&amp;time=1737127576101&amp;revision=2593" alt="image test.png" width="640" height="480" data-size="640-480" data-rotation="0" data-rsrevision="2593" /></p>&nbsp; <p></p><strong>TEST</strong></em>',
#    'lastModified': '2025-01-18T12:43:46.894Z',
#    'columnIndex': 0,
#    'files': [{'id': 3562,
#      'globalId': 'GL3562',
#      'name': '3562_test_modified.png',
#      'caption': 'API Test',
#      'contentType': 'image/x-png',
#      'created': '2025-01-17T15:26:16.101Z',
#      'size': 37993,
#      'version': 3,
#      '_links': [{'link': 'https://rspace.ntnu.no/api/v1/files/3562',
#        'rel': 'self'},
#       {'link': 'https://rspace.ntnu.no/api/v1/files/3562/file',
#        'rel': 'enclosure'}]}],
#    'listOfMaterials': [],
#    '_links': []}],
#  '_links': [{'link': 'https://rspace.ntnu.no/api/v1/documents/3559',
#    'rel': 'self'}]}

# %% [markdown]
# # Creating documents from an experiment
#
# Up to now, we have only worked with sample files and "dummy" data that does not really reflect how RSpace can be incorporated into your workflows. The biggest benefit of RSpace is that it can serve as a stable space for your results (and in some cases your raw data) _as well as_ for your notes and thoughts about your data. This can help you remember what you did half a year ago, and why you did it a particular way and not another way. Another great benefit is that RSpace enables you to share your work with your colleagues. This means that if you are struggeling with parts of the analysis for instance, you can share your work with someone else who can do that particular analysis and upload the results and explain them directly in the documents you are working on all the time!
#
# In this part, we will base our work on an example experiment that already consists of calibrated .hspy files. We could have started out with raw .mib files, but due to size limitations etc. it is easier to work directly with the .hspy files. While RSpace can handle large files, it is advised to stay below 2GB filesizes.
#
# We will start by looking at the cameralength calibration data (in the form of SAED patterns), and plot and output calibration values to ensure our calibrations are reasonable. We will also evaluate any distortions to our ring patterns. Next, we will measure the precession angle from a stack of diffraction patterns acquired with precession on but descan off. Finally, we will look at a SPED stack and create VBFs and VADFs of particular angles.

# %% [markdown]
# ## Part 1 - Calibrations

# %% [markdown]
# Let us start by creating an RSpace document where we will continously update with our results

# %%
document = client.create_document(name="Example diffraction experiment", parent_folder_id=None, tags=["API", "Example", "Diffraction", "SPED", "SAED", "TEM"])

# %%
datapath = Path(r'../example_experiment')
text = f"""
<h1>Example diffraction experiment</h1>
<h2>SAED calibration data</h2>
<p> Working on SAED patterns from {datapath.absolute()}</p>
"""
client.append_content(document['id'], text)

# %%
saed = hs.load(str(datapath/'SAED_*.hspy'), stack=False)

# %%
#Set some metadata
uploaded_files = []
for pattern in saed:
    camera_length = int(pattern.metadata.General.original_filename.split('_')[-1].replace('cm.mib', ''))
    pattern.set_experimental_parameters(
        beam_energy=200,
        camera_length=camera_length
    )
    pattern.metadata.General.title = f"{camera_length} cm"
    
    path = (datapath/pattern.metadata.General.original_filename).with_suffix('.hspy')
    
    pattern.save(path, overwrite=True)
    

    with path.open('rb') as f:
        uploaded_files.append(client.upload_file(f, caption=f"SAED {camera_length} cm: {path.stem}"))

text = f"""
SAED patterns:
<ul>
"""
text += '\n'.join([f"<li>{file['globalId']}</li>" for file in uploaded_files])
text += "\n</ul>"

print(text)
# Out:
# SAED patterns:
# <ul>
# <li>GL3618</li>
# <li>GL3619</li>
# <li>GL3620</li>
# <li>GL3621</li>
# <li>GL3622</li>
# <li>GL3623</li>
# <li>GL3624</li>
# <li>GL3625</li>
# <li>GL3626</li>
# <li>GL3627</li>
# <li>GL3628</li>
# </ul>

# %%
uploaded_files
# Out:
# [{'id': 3606,
#   'globalId': 'GL3606',
#   'name': 'SAED_NBD_alpha5_spot0p5nm_80cm.hspy',
#   'caption': 'SAED 80 cm: SAED_NBD_alpha5_spot0p5nm_80cm',
#   'contentType': 'application/octet-stream',
#   'created': '2025-01-19T13:00:49.376Z',
#   'size': 180102,
#   'version': 1,
#   '_links': [{'link': 'https://rspace.ntnu.no/api/v1/files/3606',
#     'rel': 'self'},
#    {'link': 'https://rspace.ntnu.no/api/v1/files/3606/file',
#     'rel': 'enclosure'}]}]

# %%
text
# Out:
# '\nSAED Patterns:\n<ul>\n<li><fileId=GL3583></li>\n</ul>'

# %%
_ = hs.plot.plot_images(saed, axes_decor='off', colorbar=None, norm='symlog', label='auto')
fig = plt.gcf()

fig.savefig(datapath / 'SAED.png')

with (datapath/'SAED.png').open('rb') as f: 
    file = client.upload_file(f, caption="SAED calibration patterns")
# Out:
# <div id='d7d25335-bbfb-4347-9e8f-8ce10148587d'></div>

# %%
client.append_content(document['id'], f"SAED patterns: <fileId={file['id']}>")

# %%
def cameralength(pattern, pixel_size = 55.0):
    """
    Return the actual cameralength of a diffraction pattern given a physical pixel size
    
    Parameters
    ----------
    pattern : pxm.signals.ElectronDiffraction
        The electron diffraction pattern to calculate the cameralength for.
    pixel_size : float. Optional.
        The physical pixel size of the detector in microns. Default is the pixel size for the Merlin EM 1S (55 um).

    Returns
    -------
    cameralength : float
        The actual cameralength of the diffraction pattern.
    """
    
    beam_energy = pattern.metadata.Acquisition_instrument.TEM.beam_energy
    wavelength = pxm.utils.calibration.get_electron_wavelength(beam_energy)
    return pixel_size * 1E-6 / (wavelength*pattern.axes_manager[-1].scale) *1E2

def cameralength2scale(cameralength, pixel_size = 55.0, beam_energy=200, err=0.0):
    """
    Calculates the corresponding scale given a cameralength, physical pixel size, and the beam energy.
    
    Also estimates the error in the scale given an error in the cameralength by applying Gauss Error Propagation.
    
    Parameters
    ----------
    cameralength : float
        The actual cameralength of a diffraction pattern in cm.
    pixel_size : float. Optional.
        The physical pixel size of the camera in microns. Default is the pixel size for the Merlin EM 1S (55 um).
    beam_energy : float
        The electron beam energy in kV. Default is 200 kV.
    err : float
        The standard error of the cameralength. Default is 0.

    Returns
    -------
    scale : float
        The scale of the diffraction pattern in 1/Å/px
    scale_error : float
        The estimated error of the diffraction pattern scale.
    """
    
    wavelength = pxm.utils.calibration.get_electron_wavelength(beam_energy)
    
    scale = pixel_size*1E-6 / (wavelength * cameralength*1E-2)
    
    scale_error = scale * err / cameralength #Applied Gauss Error Propagation
    
    return scale, scale_error

# %% [markdown]
# Calculate the actual cameralengths

# %%
actual_cameralengths = np.array([cameralength(pattern) for pattern in saed])
nominal_cameralengths = np.array([pattern.metadata.Acquisition_instrument.TEM.Detector.Diffraction.camera_length for pattern in saed])
# Out:
# Fitted parameters of y=ax+b:
# 	a=1.7 +/- 3.1
# 	b=3.1 +/- 0.19
# 	R^2=0.9999
# <div id='2e4b3fed-ea1e-4a8d-9714-7392a988cd88'></div>

# %% [markdown]
# Do some curve fitting

# %%
from scipy.optimize import curve_fit

def line(x, a, b):
    return a * x + b

popt, pcov = curve_fit(line, nominal_cameralengths, actual_cameralengths)
perr = np.sqrt(np.diag(pcov))
residuals = actual_cameralengths - line(nominal_cameralengths, *popt)
ss_residuals = np.sum(residuals ** 2)
ss_total = np.sum((actual_cameralengths - np.mean(actual_cameralengths)) ** 2)
r_squared = 1 - (ss_residuals/ss_total)
fit_summary = f"Fitted parameters of y=ax+b:\n\ta={popt[0]:.2g} +/- {popt[1]:.2g}\n\tb={popt[1]:.2g} +/- {perr[1]:.2g}\n\tR^2={r_squared:.4g}"

print(fit_summary)

with (datapath/'summary.txt').open('a+') as f:
    f.write(fit_summary)

# %% [markdown]
# Plot the calibrations and the curve fit

# %%
fig, ax = plt.subplots()
ax.plot(nominal_cameralengths, line(nominal_cameralengths, *popt), 'r-', label=f'Estimate $({popt[0]:.2g}\pm{perr[0]:.2g})*x + {popt[1]:.2g}\pm{perr[1]:.2g}$')
ax.plot(nominal_cameralengths, actual_cameralengths, 'bx', label='Meaurements')
ax.set_title(f'Calibration plot ($R^2={r_squared:.6g}$)')
ax.set_xlabel('Nominal cameralength (cm)')
ax.set_ylabel('Actual cameralength (cm)')
plt.legend()

fig.savefig(datapath/f'calibration_plot.png')
# Out:
# <div id='5088a602-47bf-48e8-967d-e6e26ad14a6b'></div>

# %% [markdown]
# Use the estimate to evaulate the accuracy of the diffraction pattern scales

# %%
estimated_cameralengths = line(nominal_cameralengths, *popt)
estimated_cameralengths_err = estimated_cameralengths * popt[0]*perr[0] #Error propagation on linear relationship

scales = [pattern.axes_manager[-1].scale for pattern in saed]
calibration_table = [(nom_cl, meas_cl, cl, err, s) + cameralength2scale(cl, err=err) for nom_cl, meas_cl, cl, err, s in zip(nominal_cameralengths, actual_cameralengths, estimated_cameralengths, estimated_cameralengths_err, scales)]

table = tabulate(calibration_table, headers=['Nominal CL (cm)', 'Measured CL (cm)', 'CL (cm)', 'Estimated CL error (cm)', 'Measured scale (1/Å)', 'Scale (1/Å)', 'Error (1/Å)'])

print(f"Results of calibration estimates:\n{table}")
# Out:
# Results of calibration estimates:
#   Nominal CL (cm)    Measured CL (cm)    CL (cm)    Estimated CL error (cm)    Measured scale (1/Å)    Scale (1/Å)    Error (1/Å)
# -----------------  ------------------  ---------  -------------------------  ----------------------  -------------  -------------
#                 8             17.1424    16.849                    0.139263              0.0127931      0.0130158     0.00010758
#                10             20.6117    20.2899                   0.167702              0.0106398      0.0108085     8.93361e-05
#                12             23.8769    23.7307                   0.196142              0.00918478     0.00924137    7.63829e-05
#                15             28.9788    28.8919                   0.238801              0.00756774     0.0075905     6.27379e-05
#                20             36.954     37.4939                   0.309899              0.00593451     0.00584905    4.83443e-05
#                25             45.6028    46.096                    0.380998              0.004809       0.00475755    3.93227e-05
#                30             54.6963    54.698                    0.452097              0.00400949     0.00400936    3.31386e-05
#                40             71.9012    71.9021                   0.594294              0.00305007     0.00305004    2.52095e-05
#                50             88.777     89.1062                   0.736491              0.00247028     0.00246115    2.03422e-05
#                60            106.825    106.31                     0.878688              0.00205293     0.00206287    1.70503e-05
#                80            140.721    140.718                    1.16308               0.00155843     0.00155846    1.28812e-05

# %%
dataframe = pd.DataFrame(calibration_table, columns=['Nominal CL (cm)', 'Measured CL (cm)', 'Estimated CL (cm)', 'Estimated CL error (cm)', 'Measured scale (1/Å)', 'Estimated scale (1/Å)', 'Estimated scale error (1/Å)'])

# %%
dataframe
# Out:
#     Nominal CL (cm)  Measured CL (cm)  Estimated CL (cm)  \
# 0                 8         17.142382          16.849048
# 1                10         20.611673          20.289865
# 2                12         23.876889          23.730681
# 3                15         28.978788          28.891906
# 4                20         36.954008          37.493948
# 5                25         45.602819          46.095990
# 6                30         54.696263          54.698032
# 7                40         71.901191          71.902115
# 8                50         88.776972          89.106199
# 9                60        106.824627         106.310283
# 10               80        140.720903         140.718450
#
#     Estimated CL error (cm)  Measured scale (1/Å)  Estimated scale (1/Å)  \
# 0                  0.139263              0.012793               0.013016
# 1                  0.167702              0.010640               0.010809
# 2                  0.196142              0.009185               0.009241
# 3                  0.238801              0.007568               0.007590
# 4                  0.309899              0.005935               0.005849
# 5                  0.380998              0.004809               0.004758
# 6                  0.452097              0.004009               0.004009
# 7                  0.594294              0.003050               0.003050
# 8                  0.736491              0.002470               0.002461
# 9                  0.878688              0.002053               0.002063
# 10                 1.163083              0.001558               0.001558
#
#     Estimated scale error (1/Å)
# 0                      0.000108
# 1                      0.000089
# 2                      0.000076
# 3                      0.000063
# 4                      0.000048
# 5                      0.000039
# 6                      0.000033
# 7                      0.000025
# 8                      0.000020
# 9                      0.000017
# 10                     0.000013

# %%
dataframe.to_csv(datapath / 'calibration_summary.csv', index=False)
